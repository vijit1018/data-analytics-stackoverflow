# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\vijit\\Downloads\\time_series_practice_data.csv")

# %%
df
# Out:
#             Date  Sales_USD  Foot_Traffic  Temperature_C Promo_Type  \
# 0     2023-01-01      87.15           167           -1.6        NaN
# 1     2023-01-02     117.77           236           -0.4        NaN
# 2     2023-01-03     133.00           266           -0.4   Discount
# 3     2023-01-04     140.57           335            5.4       BOGO
# 4     2023-01-05     115.44           267            7.7       BOGO
# ...          ...        ...           ...            ...        ...
# 1091  2025-12-27     153.12           338            4.1        NaN
# 1092  2025-12-28     153.16           351            1.1        NaN
# 1093  2025-12-29     213.09           454            2.8        NaN
# 1094  2025-12-30     231.58           525            3.2        NaN
# 1095  2025-12-31     216.63           392            2.9        NaN
#
#       Customer_Satisfaction
# 0                      4.65
# 1                      3.56
# 2                      4.75
# 3                      4.90
# 4                      3.92
# ...                     ...
# 1091                   4.75
# 1092                   4.37
# 1093                   3.68
# 1094                   3.93
# 1095                   3.78
#
# [1096 rows x 6 columns]

# %%
df.loc[0, 'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0      2023-01-01
# 1      2023-01-02
# 2      2023-01-03
# 3      2023-01-04
# 4      2023-01-05
#           ...
# 1091   2025-12-27
# 1092   2025-12-28
# 1093   2025-12-29
# 1094   2025-12-30
# 1095   2025-12-31
# Name: Date, Length: 1096, dtype: datetime64[us]

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Sunday'

# %%
df.loc[0, 'Date'].month_name()
# Out:
# 'January'

# %%
df['Date'].dt.day_name()
# Out:
# 0          Sunday
# 1          Monday
# 2         Tuesday
# 3       Wednesday
# 4        Thursday
#           ...
# 1091     Saturday
# 1092       Sunday
# 1093       Monday
# 1094      Tuesday
# 1095    Wednesday
# Name: Date, Length: 1096, dtype: str

# %%
df['DayofWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#            Date  Sales_USD  Foot_Traffic  Temperature_C Promo_Type  \
# 0    2023-01-01      87.15           167           -1.6        NaN
# 1    2023-01-02     117.77           236           -0.4        NaN
# 2    2023-01-03     133.00           266           -0.4   Discount
# 3    2023-01-04     140.57           335            5.4       BOGO
# 4    2023-01-05     115.44           267            7.7       BOGO
# ...         ...        ...           ...            ...        ...
# 1091 2025-12-27     153.12           338            4.1        NaN
# 1092 2025-12-28     153.16           351            1.1        NaN
# 1093 2025-12-29     213.09           454            2.8        NaN
# 1094 2025-12-30     231.58           525            3.2        NaN
# 1095 2025-12-31     216.63           392            2.9        NaN
#
#       Customer_Satisfaction  DayofWeek
# 0                      4.65     Sunday
# 1                      3.56     Monday
# 2                      4.75    Tuesday
# 3                      4.90  Wednesday
# 4                      3.92   Thursday
# ...                     ...        ...
# 1091                   4.75   Saturday
# 1092                   4.37     Sunday
# 1093                   3.68     Monday
# 1094                   3.93    Tuesday
# 1095                   3.78  Wednesday
#
# [1096 rows x 7 columns]

# %%
df['Date'].min()
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2025-12-31 00:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('1095 days 00:00:00')

# %%
filt = (df['Date'] >= '2024')
df.loc[filt]
# Out:
#            Date  Sales_USD  Foot_Traffic  Temperature_C Promo_Type  \
# 365  2024-01-01     146.02           328           -0.9   Discount
# 366  2024-01-02     160.82           366            6.4       BOGO
# 367  2024-01-03     154.58           326            3.1   Discount
# 368  2024-01-04     150.48           283            2.7        NaN
# 369  2024-01-05     157.05           345            4.7        NaN
# ...         ...        ...           ...            ...        ...
# 1091 2025-12-27     153.12           338            4.1        NaN
# 1092 2025-12-28     153.16           351            1.1        NaN
# 1093 2025-12-29     213.09           454            2.8        NaN
# 1094 2025-12-30     231.58           525            3.2        NaN
# 1095 2025-12-31     216.63           392            2.9        NaN
#
#       Customer_Satisfaction  DayofWeek
# 365                    4.84     Monday
# 366                    4.34    Tuesday
# 367                    4.53  Wednesday
# 368                    3.95   Thursday
# 369                    4.06     Friday
# ...                     ...        ...
# 1091                   4.75   Saturday
# 1092                   4.37     Sunday
# 1093                   3.68     Monday
# 1094                   3.93    Tuesday
# 1095                   3.78  Wednesday
#
# [731 rows x 7 columns]

# %%
df.set_index('Date')
# Out:
#             Sales_USD  Foot_Traffic  Temperature_C Promo_Type  \
# Date
# 2023-01-01      87.15           167           -1.6        NaN
# 2023-01-02     117.77           236           -0.4        NaN
# 2023-01-03     133.00           266           -0.4   Discount
# 2023-01-04     140.57           335            5.4       BOGO
# 2023-01-05     115.44           267            7.7       BOGO
# ...               ...           ...            ...        ...
# 2025-12-27     153.12           338            4.1        NaN
# 2025-12-28     153.16           351            1.1        NaN
# 2025-12-29     213.09           454            2.8        NaN
# 2025-12-30     231.58           525            3.2        NaN
# 2025-12-31     216.63           392            2.9        NaN
#
#             Customer_Satisfaction
# Date
# 2023-01-01                   4.65
# 2023-01-02                   3.56
# 2023-01-03                   4.75
# 2023-01-04                   4.90
# 2023-01-05                   3.92
# ...                           ...
# 2025-12-27                   4.75
# 2025-12-28                   4.37
# 2025-12-29                   3.68
# 2025-12-30                   3.93
# 2025-12-31                   3.78
#
# [1096 rows x 5 columns]

# %%
df
# Out:
#             Date  Sales_USD  Foot_Traffic  Temperature_C Promo_Type  \
# 0     2023-01-01      87.15           167           -1.6        NaN
# 1     2023-01-02     117.77           236           -0.4        NaN
# 2     2023-01-03     133.00           266           -0.4   Discount
# 3     2023-01-04     140.57           335            5.4       BOGO
# 4     2023-01-05     115.44           267            7.7       BOGO
# ...          ...        ...           ...            ...        ...
# 1091  2025-12-27     153.12           338            4.1        NaN
# 1092  2025-12-28     153.16           351            1.1        NaN
# 1093  2025-12-29     213.09           454            2.8        NaN
# 1094  2025-12-30     231.58           525            3.2        NaN
# 1095  2025-12-31     216.63           392            2.9        NaN
#
#       Customer_Satisfaction
# 0                      4.65
# 1                      3.56
# 2                      4.75
# 3                      4.90
# 4                      3.92
# ...                     ...
# 1091                   4.75
# 1092                   4.37
# 1093                   3.68
# 1094                   3.93
# 1095                   3.78
#
# [1096 rows x 6 columns]

# %%
df.loc[0, 'Date']
# Out:
# '2023-01-01'

# %%
df.loc[0]
# Out:
# Date                     2023-01-01
# Sales_USD                     87.15
# Foot_Traffic                    167
# Temperature_C                  -1.6
# Promo_Type                      NaN
# Customer_Satisfaction          4.65
# Name: 0, dtype: object
