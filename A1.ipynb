# %%
import pandas as pd

# %%
url = "https://media.githubusercontent.com/media/StackExchange/Survey/refs/heads/main/packages/archive/2019/results.csv"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.head(20)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
pd.set_option('display.max_columns', 85)

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: str

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df.loc[0, 'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: str

# %% [markdown]
# Slicing method. Same to display three rows for the column hobbyist.

# %%
df.loc[0:2, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: str

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# 29th May, 2026

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.rename(columns={'ConvertedComp': 'Salary_USD'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'Salary_USD', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.sort_values(by=['Country', 'Salary_USD'], ascending = [True, False], inplace= True)

# %%
df[['Country', 'Salary_USD']].head(60)
# Out:
#            Country  Salary_USD
# 62723  Afghanistan   1000000.0
# 50172  Afghanistan    153216.0
# 39018  Afghanistan     19152.0
# 58082  Afghanistan     17556.0
# 7056   Afghanistan     14364.0
# 22327  Afghanistan      7980.0
# 48122  Afghanistan      4464.0
# 10697  Afghanistan      3996.0
# 8112   Afghanistan      1596.0
# 29560  Afghanistan      1116.0
# 719    Afghanistan         0.0
# 28470  Afghanistan         0.0
# 6391   Afghanistan         NaN
# 7323   Afghanistan         NaN
# 12253  Afghanistan         NaN
# 26189  Afghanistan         NaN
# 28877  Afghanistan         NaN
# 32971  Afghanistan         NaN
# 37571  Afghanistan         NaN
# 39754  Afghanistan         NaN
# 42832  Afghanistan         NaN
# 44123  Afghanistan         NaN
# 45562  Afghanistan         NaN
# 46807  Afghanistan         NaN
# 49377  Afghanistan         NaN
# 50437  Afghanistan         NaN
# 51525  Afghanistan         NaN
# 58390  Afghanistan         NaN
# 59184  Afghanistan         NaN
# ...

# %%
df['Salary_USD'].nlargest(15)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# 83866    2000000.0
# 57       2000000.0
# 101      2000000.0
# 164      2000000.0
# 434      2000000.0
# Name: Salary_USD, dtype: float64

# %%
df['Salary_USD'].median()
# Out:
# np.float64(57287.0)

# %%
df.describe()
# Out:
#          Respondent     CompTotal    Salary_USD   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11  1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['Salary_USD'].count()
# Out:
# np.int64(55823)

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
country_grp = df.groupby('Country')

# %%
country_grp.get_group('United States')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 57             58  I am a developer by profession      Yes
# 101           102  I am a developer by profession       No
# 164           166  I am a developer by profession      Yes
# 434           436  I am a developer by profession      Yes
# 450           452  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                       OpenSourcer  \
# 57     Once a month or more often
# 101                         Never
# 164       Less than once per year
# 434       Less than once per year
# 450                         Never
# ...                           ...
# ...

# %%
filt = df['Country'] == 'United States'

# %%
df.loc[filt]['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              10953
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                            3585
# Some college/university study without earning a degree                                 2779
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     1113
# Associate degree                                                                        977
# Other doctoral degree (Ph.D, Ed.D., etc.)                                               673
# Primary/elementary school                                                               310
# Professional degree (JD, MD, etc.)                                                      119
# I never completed any formal education                                                   96
# Name: count, dtype: int64

# %%
(country_grp['SocialMedia'].value_counts(normalize=True) * 100).round(2).head(50).astype(str) + '%'
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                    40.54%
#                      YouTube                     24.32%
#                      I don't use social media    16.22%
#                      WhatsApp                    10.81%
#                      Instagram                     2.7%
#                      Twitter                       2.7%
#                      LinkedIn                      2.7%
# Albania              WhatsApp                    21.43%
#                      Facebook                    19.05%
#                      Instagram                   15.48%
#                      YouTube                      11.9%
#                      Twitter                      9.52%
#                      LinkedIn                     8.33%
#                      Reddit                       7.14%
#                      I don't use social media     4.76%
#                      WeChat 微信                    1.19%
# ...

# %%
(country_grp['SocialMedia'].value_counts(normalize=True) * 100).loc['India'].round(2).head(50).astype(str) + '%'
# Out:
# SocialMedia
# WhatsApp                    34.24%
# YouTube                     20.84%
# LinkedIn                    10.94%
# Facebook                     9.63%
# Instagram                    9.41%
# Twitter                      6.21%
# Reddit                       5.42%
# I don't use social media     2.86%
# Snapchat                     0.26%
# Hello                        0.06%
# WeChat 微信                    0.06%
# VK ВКонта́кте                0.05%
# Youku Tudou 优酷               0.02%
# Weibo 新浪微博                   0.01%
# Name: proportion, dtype: str

# %%
(country_grp['SocialMedia'].value_counts(normalize=True) * 100).loc['United Kingdom'].round(2).head(50).astype(str) + '%'
# Out:
# SocialMedia
# Reddit                      21.62%
# Twitter                     17.94%
# WhatsApp                    16.39%
# Facebook                    14.62%
# YouTube                     12.28%
# I don't use social media     6.71%
# Instagram                    5.73%
# LinkedIn                     3.16%
# Snapchat                     1.26%
# WeChat 微信                     0.2%
# VK ВКонта́кте                0.05%
# Weibo 新浪微博                   0.02%
# Youku Tudou 优酷               0.02%
# Name: proportion, dtype: str

# %%
country_grp['Salary_USD'].median().loc['India']
# Out:
# np.float64(10080.0)

# %%
filt = df['Country'] == 'India'

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# np.int64(3105)

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Pyhon'))
country_uses_python
# Out:
# Country
# Afghanistan  62723    False
#              50172    False
#              39018    False
#              58082    False
#              7056     False
#                       ...
# Zimbabwe     57527    False
#              60693    False
#              64307    False
#              69054    False
#              77054    False
# Name: LanguageWorkedWith, Length: 88751, dtype: bool

# %%
df['YearsCode'].unique()
# Out:
# <StringArray>
# [  'Less than 1 year',                  '7',                  '2',
#                   '6',                  '3',                  '4',
#                  '10',                 '36',                  '1',
#                   nan, 'More than 50 years',                 '20',
#                   '9',                  '5',                  '8',
#                  '31',                 '28',                 '15',
#                  '13',                 '12',                 '17',
#                  '18',                 '21',                 '35',
#                  '14',                 '25',                 '11',
#                  '19',                 '22',                 '23',
#                  '40',                 '39',                 '30',
#                  '43',                 '27',                 '33',
#                  '29',                 '24',                 '34',
#                  '16',                 '32',                 '26',
# ...

# %%
df['YearsCode'] = df['YearsCode'].replace({'Less than 1 year': 0})

# %%
df['YearsCode'].unique()
# Out:
# array([0, '7', '2', '6', '3', '4', '10', '36', '1', nan,
#        'More than 50 years', '20', '9', '5', '8', '31', '28', '15', '13',
#        '12', '17', '18', '21', '35', '14', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '32',
#        '26', '38', '44', '41', '45', '37', '47', '42', '46', '48', '50',
#        '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].replace({'More than 50 years': 51})

# %%
df['YearsCode'].unique()
# Out:
# array([0, '7', '2', '6', '3', '4', '10', '36', '1', nan, 51, '20', '9',
#        '5', '8', '31', '28', '15', '13', '12', '17', '18', '21', '35',
#        '14', '25', '11', '19', '22', '23', '40', '39', '30', '43', '27',
#        '33', '29', '24', '34', '16', '32', '26', '38', '44', '41', '45',
#        '37', '47', '42', '46', '48', '50', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].dtype
# Out:
# dtype('float64')

# %%
result = df['YearsCode'].median()

# %%
result.astype(int)
# Out:
# np.int64(9)

# %%
print(result)
# Out:
# 9.0

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 62723       63129                     I am a developer by profession      Yes
# 50172       50499  I am not primarily a developer, but I write co...      Yes
# 39018       39258                     I am a developer by profession      Yes
# 58082       58450                     I am a developer by profession      Yes
# 7056         7085                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
filt = (df['Country'] == 'India')
df[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 16703       16793                     I am a developer by profession      Yes
# 52225       52561                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88808       77339                                                NaN      Yes
# 88825       79795                                                NaN      Yes
# 88852       83862                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88864       86012                                                NaN      Yes
#
# ...

# %%
india_df = df[filt]

# %%
india_df.to_csv('C:/Users/vijit/Downloads/india_df.csv')

# %%
india_df.to_json('C:/Users/vijit/Downloads/india_df.json')

# %%
from sq
