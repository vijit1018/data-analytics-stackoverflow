# %%
import pandas as pd
import numpy as np

# %%
people = {
    "first": ["Corey", "Jane", "John", "Chris", np.nan, None, 'NA'],
    "last": ["Schafer", "Doe", "Doe", "Schafer", np.nan, np.nan, "Missing"],
    "email": ["CoreyMSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com", None, np.nan, "Anonymous@gmail.com", 'NA'],
    "age":['33','53', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       53
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                      NaN       36
# 4    NaN      NaN                      NaN      NaN
# 5    NaN      NaN      Anonymous@gmail.com      NaN
# 6     NA  Missing                       NA  Missing

# %%
df['last']
# Out:
# 0    Schafer
# 1        Doe
# 2        Doe
# Name: last, dtype: str

# %%
df['last'] == "Doe"
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = df['last'] == "Doe"
df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %% [markdown]
# In a similar fashion, we can also execute this using loc

# %%
df.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %%
filte = (df['first'] == "John") & (df['last'] == "Doe")

# %%
df[filte]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@gmail.com

# %% [markdown]
# 29th May, 2026

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.loc[2, ['last', 'email']] = ['Tait', 'johntait@gmail.com']

# %%
df
# Out:
#    FIRST     LAST                    EMAIL  last               email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN                 NaN
# 1   Jane      Doe        JaneDoe@gmail.com   NaN                 NaN
# 2   John      Doe        JohnDoe@gmail.com  Tait  johntait@gmail.com

# %%
df
# Out:
#    FIRST     LAST                    EMAIL  last               email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN                 NaN
# 1   Jane      Doe        JaneDoe@gmail.com   NaN                 NaN
# 2   John      Doe        JohnDoe@gmail.com  Tait  johntait@gmail.com

# %% [markdown]
# How to perform operation on all the rows of a particular column

# %%
df['email'].str.lower()
# Out:
# 0                   NaN
# 1                   NaN
# 2    johntait@gmail.com
# Name: email, dtype: str

# %%
df
# Out:
#    FIRST     LAST                    EMAIL  last               email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN                 NaN
# 1   Jane      Doe        JaneDoe@gmail.com   NaN                 NaN
# 2   John      Doe        JohnDoe@gmail.com  Tait  johntait@gmail.com

# %%
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#    FIRST     LAST                    EMAIL  last               email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN                 NaN
# 1   Jane      Doe        JaneDoe@gmail.com   NaN                 NaN
# 2   John      Doe        JohnDoe@gmail.com  Tait  johntait@gmail.com

# %%
df

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df

# %%
df.map(len)

# %%
df['first'].map({'Corey': 'Jorey', 'Jane': 'Wane'})

# %%
df['first'].replace({'Corey': 'Jorey', 'Jane': 'Wane'})

# %%
df

# %%
df.drop('last', axis=1)

# %%
df

# %%
df = df.drop('last', axis=1)

# %%
df

# %%
df = df.drop('email', axis=1)

# %%
df

# %%
df.columns

# %%
df.columns = df.columns.str.lower()

# %%
df

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df

# %%
df[['first1c', 'first2c']] = df['full_name'].str.split(' ', expand=True)

# %%
df

# %%
df = df.drop(columns = ['first1c', 'first2c'])

# %%
df

# %%
df = df.drop('full_name', axis=1)

# %%
df

# %%
people = {
    "first": ["Corey", "Jane"],
    "last": ["Stark", "Rogers"],
    "email": ["ironman@avenge.com", "cap@avenge.com"]
}
df2 = pd.DataFrame(people)

# %%
df2

# %%
df.append(df2, ignore_index = True)

# %%
df = pd.concat([df,df2], ignore_index=True)

# %%
df

# %%
df = df.drop(index=4)

# %%
df

# %%
df.sort_values(by='last')

# %%
df.sort_values(by='last', ascending=False)

# %%
df.sort_index()

# %%
df.sort_values(by='LAST')

# %%
df

# %%
df.loc[len(df)] = ['Adam', 'Doe', 'adamdoe@gmail.com', 'NA', 'NA']

# %%
df
# Out:
#    FIRST     LAST                    EMAIL  last               email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN                 NaN
# 1   Jane      Doe        JaneDoe@gmail.com   NaN                 NaN
# 2   John      Doe        JohnDoe@gmail.com  Tait  johntait@gmail.com
# 3   Adam      Doe        adamdoe@gmail.com    NA                  NA

# %%
df = df.replace('NA', np.nan)

# %%
df
# Out:
#    FIRST     LAST                    EMAIL  last               email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN                 NaN
# 1   Jane      Doe        JaneDoe@gmail.com   NaN                 NaN
# 2   John      Doe        JohnDoe@gmail.com  Tait  johntait@gmail.com
# 3   Adam      Doe        adamdoe@gmail.com   NaN                 NaN

# %%
df = df.drop(columns=['last', 'email'])

# %%
df
# Out:
#    FIRST     LAST                    EMAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe        adamdoe@gmail.com

# %%
df.columns.str.lower()
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df.sort_values(by=['last','first'], ascending = [False, True])
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# June 04, 2026

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       53
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                      NaN       36
# 4    NaN      NaN                      NaN      NaN
# 5    NaN      NaN      Anonymous@gmail.com      NaN
# 6     NA  Missing                       NA  Missing

# %%
df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       53
# 2   John      Doe        JohnDoe@gmail.com       63
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how = 'all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       53
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                      NaN       36
# 5    NaN      NaN      Anonymous@gmail.com      NaN
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       53
# 2   John      Doe        JohnDoe@gmail.com       63
# 5    NaN      NaN      Anonymous@gmail.com      NaN
# 6     NA  Missing                       NA  Missing

# %%
df.replace('NA', np.nan, inplace=True)
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       53
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                      NaN       36
# 4    NaN      NaN                      NaN      NaN
# 5    NaN      NaN      Anonymous@gmail.com      NaN
# 6    NaN  Missing                      NaN  Missing

# %%
df.replace('Missing', np.nan, inplace=True)
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@gmail.com   53
# 2   John      Doe        JohnDoe@gmail.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@gmail.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@gmail.com  53
# 2   John      Doe        JohnDoe@gmail.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@gmail.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object
